# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_no_dropout = np.load('results/results_no_dropout.npy')
data_standard = np.load('results/result_standard_dropout.npy')
data_maxpool = np.load('results/result_maxpool_dropout.npy')
data_both = np.load('results/result_both.npy')

# %%
val_set = np.arange(.99, .01, -.10)

for i, v in enumerate(val_set):        
    for j in range(1):
        plt.plot(data_no_dropout[0][j][:], label=str(i)+'_No')
        plt.plot(data_standard[0][j][:], label=str(i)+ '_standard')
        plt.plot(data_maxpool[0][j][:], label=str(i)+'_MaxPool')
        plt.plot(data_both[0][j][:], label=str(i)+'_Both')
    
plt.legend()
plt.title('Loss')

# %%
for i in range(data.shape[1]):
    plt.plot(data[1][i][:], label=i)
plt.legend()
plt.title('Validation loss')

# %%
for i in range(data.shape[1]):
    plt.plot(data[2][i][:], label=i)
plt.legend()
plt.title('mIOU')

# %%
for i in range(data.shape[1]):
    plt.plot(data[3][i][:], label=i)
plt.legend()
plt.title('Validation mIOU')
