# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = '/media/charley/CHARLEY/PhD_Work/Datasets/data-science-bowl-2018/stage1_train/'
TEST_PATH = '/media/charley/CHARLEY/PhD_Work/Datasets/data-science-bowl-2018/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:18<00:00,  8.52it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:01<00:00, 64.82it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 256)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 128)  131200      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   32832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 32)   8224        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 16) 2064        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 16) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 1)  17          conv2d_18[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
# 603/603 [==============================] - 11s 18ms/step - loss: 0.4850 - mean_iou: 0.4076 - val_loss: 0.2986 - val_mean_iou: 0.4234
#
# Epoch 00001: val_loss improved from inf to 0.29863, saving model to model-dsbowl2018-1.h5
# Epoch 2/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.2421 - mean_iou: 0.4252 - val_loss: 0.2031 - val_mean_iou: 0.4361
#
# Epoch 00002: val_loss improved from 0.29863 to 0.20311, saving model to model-dsbowl2018-1.h5
# Epoch 3/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.1504 - mean_iou: 0.4731 - val_loss: 0.1207 - val_mean_iou: 0.5143
#
# Epoch 00003: val_loss improved from 0.20311 to 0.12070, saving model to model-dsbowl2018-1.h5
# Epoch 4/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.1166 - mean_iou: 0.5511 - val_loss: 0.1283 - val_mean_iou: 0.5804
#
# Epoch 00004: val_loss did not improve from 0.12070
# Epoch 5/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.1142 - mean_iou: 0.6025 - val_loss: 0.1122 - val_mean_iou: 0.6210
#
# Epoch 00005: val_loss improved from 0.12070 to 0.11217, saving model to model-dsbowl2018-1.h5
# Epoch 6/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.1054 - mean_iou: 0.6379 - val_loss: 0.1037 - val_mean_iou: 0.6522
#
# Epoch 00006: val_loss improved from 0.11217 to 0.10371, saving model to model-dsbowl2018-1.h5
# Epoch 7/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.1002 - mean_iou: 0.6639 - val_loss: 0.0946 - val_mean_iou: 0.6750
#
# Epoch 00007: val_loss improved from 0.10371 to 0.09464, saving model to model-dsbowl2018-1.h5
# Epoch 8/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0914 - mean_iou: 0.6848 - val_loss: 0.0903 - val_mean_iou: 0.6944
#
# Epoch 00008: val_loss improved from 0.09464 to 0.09033, saving model to model-dsbowl2018-1.h5
# Epoch 9/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0889 - mean_iou: 0.7025 - val_loss: 0.1018 - val_mean_iou: 0.7097
#
# Epoch 00009: val_loss did not improve from 0.09033
# Epoch 10/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0873 - mean_iou: 0.7163 - val_loss: 0.0906 - val_mean_iou: 0.7224
#
# Epoch 00010: val_loss did not improve from 0.09033
# Epoch 11/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0847 - mean_iou: 0.7278 - val_loss: 0.0848 - val_mean_iou: 0.7330
#
# Epoch 00011: val_loss improved from 0.09033 to 0.08476, saving model to model-dsbowl2018-1.h5
# Epoch 12/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0818 - mean_iou: 0.7378 - val_loss: 0.0811 - val_mean_iou: 0.7425
#
# Epoch 00012: val_loss improved from 0.08476 to 0.08110, saving model to model-dsbowl2018-1.h5
# Epoch 13/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0813 - mean_iou: 0.7466 - val_loss: 0.0810 - val_mean_iou: 0.7506
#
# Epoch 00013: val_loss improved from 0.08110 to 0.08096, saving model to model-dsbowl2018-1.h5
# Epoch 14/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0812 - mean_iou: 0.7543 - val_loss: 0.0840 - val_mean_iou: 0.7579
#
# Epoch 00014: val_loss did not improve from 0.08096
# Epoch 15/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0772 - mean_iou: 0.7612 - val_loss: 0.0772 - val_mean_iou: 0.7644
#
# Epoch 00015: val_loss improved from 0.08096 to 0.07722, saving model to model-dsbowl2018-1.h5
# Epoch 16/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0792 - mean_iou: 0.7672 - val_loss: 0.0771 - val_mean_iou: 0.7698
#
# Epoch 00016: val_loss improved from 0.07722 to 0.07711, saving model to model-dsbowl2018-1.h5
# Epoch 17/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0768 - mean_iou: 0.7725 - val_loss: 0.0797 - val_mean_iou: 0.7749
#
# Epoch 00017: val_loss did not improve from 0.07711
# Epoch 18/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0776 - mean_iou: 0.7770 - val_loss: 0.0778 - val_mean_iou: 0.7793
#
# Epoch 00018: val_loss did not improve from 0.07711
# Epoch 19/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0754 - mean_iou: 0.7815 - val_loss: 0.0734 - val_mean_iou: 0.7835
#
# Epoch 00019: val_loss improved from 0.07711 to 0.07337, saving model to model-dsbowl2018-1.h5
# Epoch 20/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0732 - mean_iou: 0.7855 - val_loss: 0.0739 - val_mean_iou: 0.7874
#
# Epoch 00020: val_loss did not improve from 0.07337
# Epoch 21/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0765 - mean_iou: 0.7893 - val_loss: 0.0745 - val_mean_iou: 0.7908
#
# Epoch 00021: val_loss did not improve from 0.07337
# Epoch 22/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0728 - mean_iou: 0.7924 - val_loss: 0.0765 - val_mean_iou: 0.7940
#
# Epoch 00022: val_loss did not improve from 0.07337
# Epoch 23/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0741 - mean_iou: 0.7955 - val_loss: 0.0750 - val_mean_iou: 0.7969
#
# Epoch 00023: val_loss did not improve from 0.07337
# Epoch 24/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0723 - mean_iou: 0.7983 - val_loss: 0.0713 - val_mean_iou: 0.7995
#
# Epoch 00024: val_loss improved from 0.07337 to 0.07134, saving model to model-dsbowl2018-1.h5
# Epoch 25/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0712 - mean_iou: 0.8009 - val_loss: 0.0733 - val_mean_iou: 0.8021
#
# Epoch 00025: val_loss did not improve from 0.07134
# Epoch 26/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0704 - mean_iou: 0.8033 - val_loss: 0.0697 - val_mean_iou: 0.8045
#
# Epoch 00026: val_loss improved from 0.07134 to 0.06970, saving model to model-dsbowl2018-1.h5
# Epoch 27/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0702 - mean_iou: 0.8057 - val_loss: 0.0737 - val_mean_iou: 0.8068
#
# Epoch 00027: val_loss did not improve from 0.06970
# Epoch 28/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0695 - mean_iou: 0.8078 - val_loss: 0.0709 - val_mean_iou: 0.8089
#
# Epoch 00028: val_loss did not improve from 0.06970
# Epoch 29/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0699 - mean_iou: 0.8100 - val_loss: 0.0708 - val_mean_iou: 0.8109
#
# Epoch 00029: val_loss did not improve from 0.06970
# Epoch 30/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0705 - mean_iou: 0.8118 - val_loss: 0.0696 - val_mean_iou: 0.8128
#
# Epoch 00030: val_loss improved from 0.06970 to 0.06957, saving model to model-dsbowl2018-1.h5
# Epoch 31/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0687 - mean_iou: 0.8137 - val_loss: 0.0695 - val_mean_iou: 0.8145
#
# Epoch 00031: val_loss improved from 0.06957 to 0.06951, saving model to model-dsbowl2018-1.h5
# Epoch 32/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0680 - mean_iou: 0.8155 - val_loss: 0.0666 - val_mean_iou: 0.8163
#
# Epoch 00032: val_loss improved from 0.06951 to 0.06660, saving model to model-dsbowl2018-1.h5
# Epoch 33/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0686 - mean_iou: 0.8171 - val_loss: 0.0676 - val_mean_iou: 0.8179
#
# Epoch 00033: val_loss did not improve from 0.06660
# Epoch 34/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0678 - mean_iou: 0.8187 - val_loss: 0.0749 - val_mean_iou: 0.8194
#
# Epoch 00034: val_loss did not improve from 0.06660
# Epoch 35/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0662 - mean_iou: 0.8201 - val_loss: 0.0662 - val_mean_iou: 0.8209
#
# Epoch 00035: val_loss improved from 0.06660 to 0.06619, saving model to model-dsbowl2018-1.h5
# Epoch 36/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0661 - mean_iou: 0.8216 - val_loss: 0.0700 - val_mean_iou: 0.8223
#
# Epoch 00036: val_loss did not improve from 0.06619
# Epoch 37/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0664 - mean_iou: 0.8230 - val_loss: 0.0725 - val_mean_iou: 0.8237
#
# Epoch 00037: val_loss did not improve from 0.06619
# Epoch 38/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0657 - mean_iou: 0.8243 - val_loss: 0.0682 - val_mean_iou: 0.8249
# Epoch 00038: val_loss did not improve from 0.06619
# Epoch 39/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0655 - mean_iou: 0.8255 - val_loss: 0.0690 - val_mean_iou: 0.8261
#
# Epoch 00039: val_loss did not improve from 0.06619
# Epoch 40/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0649 - mean_iou: 0.8267 - val_loss: 0.0638 - val_mean_iou: 0.8273
#
# Epoch 00040: val_loss improved from 0.06619 to 0.06377, saving model to model-dsbowl2018-1.h5
# Epoch 41/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0654 - mean_iou: 0.8279 - val_loss: 0.0702 - val_mean_iou: 0.8284
#
# Epoch 00041: val_loss did not improve from 0.06377
# Epoch 42/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0650 - mean_iou: 0.8290 - val_loss: 0.0706 - val_mean_iou: 0.8295
#
# Epoch 00042: val_loss did not improve from 0.06377
# Epoch 43/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0632 - mean_iou: 0.8301 - val_loss: 0.0678 - val_mean_iou: 0.8306
#
# Epoch 00043: val_loss did not improve from 0.06377
# Epoch 44/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0635 - mean_iou: 0.8311 - val_loss: 0.0658 - val_mean_iou: 0.8317
#
# Epoch 00044: val_loss did not improve from 0.06377
# Epoch 45/50
# 603/603 [==============================] - 3s 5ms/step - loss: 0.0638 - mean_iou: 0.8322 - val_loss: 0.0677 - val_mean_iou: 0.8327
#
# Epoch 00045: val_loss did not improve from 0.06377
# Epoch 00045: early stopping

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 2s 3ms/step
# 67/67 [==============================] - 0s 1ms/step
# 65/65 [==============================] - 0s 3ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %%
results.history.keys()

# %%
plt.plot(results.history['val_loss'])
plt.plot(results.history['loss'])

# %%
plt.plot(results.history['val_mean_iou'])
plt.plot(results.history['mean_iou'])
